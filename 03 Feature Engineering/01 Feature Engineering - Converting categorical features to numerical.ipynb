# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %%
#https://www.kaggle.com/sakshigoyal7/credit-card-customers
bankchurners = pd.read_csv('../data_source/BankChurners.csv')
bankchurners.head(10)
# Out:
#    CLIENTNUM     Attrition_Flag  Customer_Age Gender  Dependent_count  \
# 0  768805383  Existing Customer            45      M                3
# 1  818770008  Existing Customer            49      F                5
# 2  713982108  Existing Customer            51      M                3
# 3  769911858  Existing Customer            40      F                4
# 4  709106358  Existing Customer            40      M                3
# 5  713061558  Existing Customer            44      M                2
# 6  810347208  Existing Customer            51      M                4
# 7  818906208  Existing Customer            32      M                0
# 8  710930508  Existing Customer            37      M                3
# 9  719661558  Existing Customer            48      M                2
#
#   Education_Level Marital_Status Income_Category Card_Category  \
# 0     High School        Married     $60K - $80K          Blue
# 1        Graduate         Single  Less than $40K          Blue
# ...

# %%
bankchurners.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10127 entries, 0 to 10126
# Data columns (total 23 columns):
#  #   Column                                                                                                                              Non-Null Count  Dtype
# ---  ------                                                                                                                              --------------  -----
#  0   CLIENTNUM                                                                                                                           10127 non-null  int64
#  1   Attrition_Flag                                                                                                                      10127 non-null  object
#  2   Customer_Age                                                                                                                        10127 non-null  int64
# ...

# %%
#Dropping last two columns as kaggle description indicates they were specific to a project - not from the raw data
bankchurners20columns = bankchurners.drop(['Naive_Bayes_Classifier_Attrition_Flag_Card_Category_Contacts_Count_12_mon_Dependent_count_Education_Level_Months_Inactive_12_mon_1', 
         'Naive_Bayes_Classifier_Attrition_Flag_Card_Category_Contacts_Count_12_mon_Dependent_count_Education_Level_Months_Inactive_12_mon_2'], axis = 1)
bankchurners20columns.columns
# Out:
# Index(['CLIENTNUM', 'Attrition_Flag', 'Customer_Age', 'Gender',
#        'Dependent_count', 'Education_Level', 'Marital_Status',
#        'Income_Category', 'Card_Category', 'Months_on_book',
#        'Total_Relationship_Count', 'Months_Inactive_12_mon',
#        'Contacts_Count_12_mon', 'Credit_Limit', 'Total_Revolving_Bal',
#        'Avg_Open_To_Buy', 'Total_Amt_Chng_Q4_Q1', 'Total_Trans_Amt',
#        'Total_Trans_Ct', 'Total_Ct_Chng_Q4_Q1', 'Avg_Utilization_Ratio'],
#       dtype='object')

# %% [markdown]
# # Handle categorical features

# %% [markdown]
# ## Ordinal Categorical Features
# one class is higher than another.
# https://heartbeat.fritz.ai/a-practical-guide-to-feature-engineering-in-python-8326e40747c8

# %% [markdown]
# * Column - Education_Level

# %%
# identify unique classes
bankchurners20columns['Education_Level'].unique()
# Out:
# array(['High School', 'Graduate', 'Uneducated', 'Unknown', 'College',
#        'Post-Graduate', 'Doctorate'], dtype=object)

# %%
map_education = {"Unknown" : 1, "Uneducated": 2, "High School": 3, "College": 4, "Graduate":5, "Post-Graduate":6, "Doctorate":7}
map_education
# Out:
# {'Unknown': 1,
#  'Uneducated': 2,
#  'High School': 3,
#  'College': 4,
#  'Graduate': 5,
#  'Post-Graduate': 6,
#  'Doctorate': 7}

# %%
bankchurners20columns['Education_Level'].value_counts()
# Out:
# Graduate         3128
# High School      2013
# Unknown          1519
# Uneducated       1487
# College          1013
# Post-Graduate     516
# Doctorate         451
# Name: Education_Level, dtype: int64

# %%
#Map defined classes to column values
bankchurners20columns['Education_Level'] = bankchurners20columns['Education_Level'].map(map_education)
bankchurners20columns['Education_Level'].value_counts()
# Out:
# 5    3128
# 3    2013
# 1    1519
# 2    1487
# 4    1013
# 6     516
# 7     451
# Name: Education_Level, dtype: int64

# %%
bankchurners.head(5)
# Out:
#    CLIENTNUM     Attrition_Flag  Customer_Age Gender  Dependent_count  \
# 0  768805383  Existing Customer            45      M                3
# 1  818770008  Existing Customer            49      F                5
# 2  713982108  Existing Customer            51      M                3
# 3  769911858  Existing Customer            40      F                4
# 4  709106358  Existing Customer            40      M                3
#
#   Education_Level Marital_Status Income_Category Card_Category  \
# 0     High School        Married     $60K - $80K          Blue
# 1        Graduate         Single  Less than $40K          Blue
# 2        Graduate        Married    $80K - $120K          Blue
# 3     High School        Unknown  Less than $40K          Blue
# 4      Uneducated        Married     $60K - $80K          Blue
#
#    Months_on_book  ...  Credit_Limit  Total_Revolving_Bal  Avg_Open_To_Buy  \
# 0              39  ...       12691.0                  777          11914.0
# ...

# %%
bankchurners20columns.head(5)
# Out:
#    CLIENTNUM     Attrition_Flag  Customer_Age Gender  Dependent_count  \
# 0  768805383  Existing Customer            45      M                3
# 1  818770008  Existing Customer            49      F                5
# 2  713982108  Existing Customer            51      M                3
# 3  769911858  Existing Customer            40      F                4
# 4  709106358  Existing Customer            40      M                3
#
#    Education_Level Marital_Status Income_Category Card_Category  \
# 0                3        Married     $60K - $80K          Blue
# 1                5         Single  Less than $40K          Blue
# 2                5        Married    $80K - $120K          Blue
# 3                3        Unknown  Less than $40K          Blue
# 4                2        Married     $60K - $80K          Blue
#
#    Months_on_book  ...  Months_Inactive_12_mon  Contacts_Count_12_mon  \
# 0              39  ...                       1                      3
# ...

# %% [markdown]
# **Ordinal Categorical Feature**
# * Column - Income_Category

# %%
# identify unique classes
bankchurners20columns['Income_Category'].unique()
# Out:
# array(['$60K - $80K', 'Less than $40K', '$80K - $120K', '$40K - $60K',
#        '$120K +', 'Unknown'], dtype=object)

# %%
map_income = {"Unknown":1, "Less than $40K" : 2, "$40K - $60K": 3, "$60K - $80K": 4, "$80K - $120K": 5, "$120K +":6}
map_income
# Out:
# {'Unknown': 1,
#  'Less than $40K': 2,
#  '$40K - $60K': 3,
#  '$60K - $80K': 4,
#  '$80K - $120K': 5,
#  '$120K +': 6}

# %%
bankchurners20columns['Income_Category'].value_counts()
# Out:
# Less than $40K    3561
# $40K - $60K       1790
# $80K - $120K      1535
# $60K - $80K       1402
# Unknown           1112
# $120K +            727
# Name: Income_Category, dtype: int64

# %%
#Map defined classes to column values
bankchurners20columns['Income_Category'] = bankchurners20columns['Income_Category'].map(map_income)
bankchurners20columns['Income_Category'].value_counts()
# Out:
# 2    3561
# 3    1790
# 5    1535
# 4    1402
# 1    1112
# 6     727
# Name: Income_Category, dtype: int64

# %%
bankchurners.head(5)
# Out:
#    CLIENTNUM     Attrition_Flag  Customer_Age Gender  Dependent_count  \
# 0  768805383  Existing Customer            45      M                3
# 1  818770008  Existing Customer            49      F                5
# 2  713982108  Existing Customer            51      M                3
# 3  769911858  Existing Customer            40      F                4
# 4  709106358  Existing Customer            40      M                3
#
#   Education_Level Marital_Status Income_Category Card_Category  \
# 0     High School        Married     $60K - $80K          Blue
# 1        Graduate         Single  Less than $40K          Blue
# 2        Graduate        Married    $80K - $120K          Blue
# 3     High School        Unknown  Less than $40K          Blue
# 4      Uneducated        Married     $60K - $80K          Blue
#
#    Months_on_book  ...  Credit_Limit  Total_Revolving_Bal  Avg_Open_To_Buy  \
# 0              39  ...       12691.0                  777          11914.0
# ...

# %%
bankchurners20columns.head(5)
# Out:
#    CLIENTNUM     Attrition_Flag  Customer_Age Gender  Dependent_count  \
# 0  768805383  Existing Customer            45      M                3
# 1  818770008  Existing Customer            49      F                5
# 2  713982108  Existing Customer            51      M                3
# 3  769911858  Existing Customer            40      F                4
# 4  709106358  Existing Customer            40      M                3
#
#    Education_Level Marital_Status  Income_Category Card_Category  \
# 0                3        Married                4          Blue
# 1                5         Single                2          Blue
# 2                5        Married                5          Blue
# 3                3        Unknown                2          Blue
# 4                2        Married                4          Blue
#
#    Months_on_book  ...  Months_Inactive_12_mon  Contacts_Count_12_mon  \
# 0              39  ...                       1                      3
# ...

# %% [markdown]
# **Ordinal Categorical Feature**
# * Column - Card_Category

# %%
# identify unique classes
bankchurners20columns['Card_Category'].unique()
# Out:
# array(['Blue', 'Gold', 'Silver', 'Platinum'], dtype=object)

# %%
map_cards = {"Blue":1, "Silver" : 2, "Gold": 3, "Platinum": 4}
map_cards
# Out:
# {'Blue': 1, 'Silver': 2, 'Gold': 3, 'Platinum': 4}

# %%
bankchurners20columns['Card_Category'].value_counts()
# Out:
# Blue        9436
# Silver       555
# Gold         116
# Platinum      20
# Name: Card_Category, dtype: int64

# %%
#Map defined classes to column values
bankchurners20columns['Card_Category'] = bankchurners20columns['Card_Category'].map(map_cards)
bankchurners20columns['Card_Category'].value_counts()
# Out:
# 1    9436
# 2     555
# 3     116
# 4      20
# Name: Card_Category, dtype: int64

# %%
bankchurners.head(5)
# Out:
#    CLIENTNUM     Attrition_Flag  Customer_Age Gender  Dependent_count  \
# 0  768805383  Existing Customer            45      M                3
# 1  818770008  Existing Customer            49      F                5
# 2  713982108  Existing Customer            51      M                3
# 3  769911858  Existing Customer            40      F                4
# 4  709106358  Existing Customer            40      M                3
#
#   Education_Level Marital_Status Income_Category Card_Category  \
# 0     High School        Married     $60K - $80K          Blue
# 1        Graduate         Single  Less than $40K          Blue
# 2        Graduate        Married    $80K - $120K          Blue
# 3     High School        Unknown  Less than $40K          Blue
# 4      Uneducated        Married     $60K - $80K          Blue
#
#    Months_on_book  ...  Credit_Limit  Total_Revolving_Bal  Avg_Open_To_Buy  \
# 0              39  ...       12691.0                  777          11914.0
# ...

# %%
bankchurners20columns.head(5)
# Out:
#    CLIENTNUM     Attrition_Flag  Customer_Age Gender  Dependent_count  \
# 0  768805383  Existing Customer            45      M                3
# 1  818770008  Existing Customer            49      F                5
# 2  713982108  Existing Customer            51      M                3
# 3  769911858  Existing Customer            40      F                4
# 4  709106358  Existing Customer            40      M                3
#
#    Education_Level Marital_Status  Income_Category  Card_Category  \
# 0                3        Married                4              1
# 1                5         Single                2              1
# 2                5        Married                5              1
# 3                3        Unknown                2              1
# 4                2        Married                4              1
#
#    Months_on_book  ...  Months_Inactive_12_mon  Contacts_Count_12_mon  \
# 0              39  ...                       1                      3
# ...

# %% [markdown]
# ## Non-ordinal Categorical Features
# No specific order of class

# %% [markdown]
# * Column - Gender

# %%
bankchurners20columns['Gender'].value_counts()
# Out:
# F    5358
# M    4769
# Name: Gender, dtype: int64

# %%
#Label encoding
#Import library
from sklearn.preprocessing import LabelEncoder

# %%
#Create encoder
label_encoderGender = LabelEncoder()

# %%
#Fit data to encoder
label_encoderGender.fit(bankchurners20columns['Gender'])
# Out:
# LabelEncoder()

# %%
#transform - CAN ONLY RUN ONCE
bankchurners20columns['Gender'] = label_encoderGender.transform(bankchurners20columns['Gender'])

# %%
bankchurners20columns['Gender'].value_counts()
# Out:
# 0    5358
# 1    4769
# Name: Gender, dtype: int64

# %%
bankchurners20columns.head(10)
# Out:
#    CLIENTNUM     Attrition_Flag  Customer_Age  Gender  Dependent_count  \
# 0  768805383  Existing Customer            45       1                3
# 1  818770008  Existing Customer            49       0                5
# 2  713982108  Existing Customer            51       1                3
# 3  769911858  Existing Customer            40       0                4
# 4  709106358  Existing Customer            40       1                3
# 5  713061558  Existing Customer            44       1                2
# 6  810347208  Existing Customer            51       1                4
# 7  818906208  Existing Customer            32       1                0
# 8  710930508  Existing Customer            37       1                3
# 9  719661558  Existing Customer            48       1                2
#
#    Education_Level Marital_Status  Income_Category  Card_Category  \
# 0                3        Married                4              1
# ...

# %% [markdown]
# **Non-ordinal Categorical Feature**
# * Column - Marital_Status

# %%
bankchurners20columns['Marital_Status'].value_counts()
# Out:
# Married     4687
# Single      3943
# Unknown      749
# Divorced     748
# Name: Marital_Status, dtype: int64

# %%
#Create encoder
label_encodermarital = LabelEncoder()

# %%
#Fit data to encoder
label_encodermarital.fit(bankchurners20columns['Marital_Status'])
# Out:
# LabelEncoder()

# %%
#transform - CAN ONLY RUN ONCE
bankchurners20columns['Marital_Status'] = label_encodermarital.transform(bankchurners20columns['Marital_Status'])

# %%
bankchurners20columns.head(10)
# Out:
#    CLIENTNUM     Attrition_Flag  Customer_Age  Gender  Dependent_count  \
# 0  768805383  Existing Customer            45       1                3
# 1  818770008  Existing Customer            49       0                5
# 2  713982108  Existing Customer            51       1                3
# 3  769911858  Existing Customer            40       0                4
# 4  709106358  Existing Customer            40       1                3
# 5  713061558  Existing Customer            44       1                2
# 6  810347208  Existing Customer            51       1                4
# 7  818906208  Existing Customer            32       1                0
# 8  710930508  Existing Customer            37       1                3
# 9  719661558  Existing Customer            48       1                2
#
#    Education_Level  Marital_Status  Income_Category  Card_Category  \
# 0                3               1                4              1
# ...

# %%
bankchurners20columns['Marital_Status'].value_counts()
# Out:
# 1    4687
# 2    3943
# 3     749
# 0     748
# Name: Marital_Status, dtype: int64

# %%
bankchurners.head(10)
# Out:
#    CLIENTNUM     Attrition_Flag  Customer_Age Gender  Dependent_count  \
# 0  768805383  Existing Customer            45      M                3
# 1  818770008  Existing Customer            49      F                5
# 2  713982108  Existing Customer            51      M                3
# 3  769911858  Existing Customer            40      F                4
# 4  709106358  Existing Customer            40      M                3
# 5  713061558  Existing Customer            44      M                2
# 6  810347208  Existing Customer            51      M                4
# 7  818906208  Existing Customer            32      M                0
# 8  710930508  Existing Customer            37      M                3
# 9  719661558  Existing Customer            48      M                2
#
#   Education_Level Marital_Status Income_Category Card_Category  \
# 0     High School        Married     $60K - $80K          Blue
# 1        Graduate         Single  Less than $40K          Blue
# ...

# %%
bankchurners20columns.head(10)
# Out:
#    CLIENTNUM     Attrition_Flag  Customer_Age  Gender  Dependent_count  \
# 0  768805383  Existing Customer            45       1                3
# 1  818770008  Existing Customer            49       0                5
# 2  713982108  Existing Customer            51       1                3
# 3  769911858  Existing Customer            40       0                4
# 4  709106358  Existing Customer            40       1                3
# 5  713061558  Existing Customer            44       1                2
# 6  810347208  Existing Customer            51       1                4
# 7  818906208  Existing Customer            32       1                0
# 8  710930508  Existing Customer            37       1                3
# 9  719661558  Existing Customer            48       1                2
#
#    Education_Level  Marital_Status  Income_Category  Card_Category  \
# 0                3               1                4              1
# ...

# %%
bankchurnersencoded = bankchurners20columns.copy()
bankchurnersencoded
# Out:
#        CLIENTNUM     Attrition_Flag  Customer_Age  Gender  Dependent_count  \
# 0      768805383  Existing Customer            45       1                3
# 1      818770008  Existing Customer            49       0                5
# 2      713982108  Existing Customer            51       1                3
# 3      769911858  Existing Customer            40       0                4
# 4      709106358  Existing Customer            40       1                3
# ...          ...                ...           ...     ...              ...
# 10122  772366833  Existing Customer            50       1                2
# 10123  710638233  Attrited Customer            41       1                2
# 10124  716506083  Attrited Customer            44       0                1
# 10125  717406983  Attrited Customer            30       1                2
# 10126  714337233  Attrited Customer            43       0                2
#
# ...

# %%
bankchurnersencoded.to_csv("bankchurnersencoded.csv", index=False, header=True)

# %% [markdown]
# Save encoding - doesn't work

# %%
# from pickle import dump

# %%
# save the encoder
# dump(label_encoderGender, open('label_encoderGender.pkl', 'wb'))

# %%
#Code to load the scaler when required
# from pickle import load

# %%
# label_encoderGenderX = load(open('label_encoderGender.pkl', 'rb'))

# %%
#transform
# bankchurners20columns['Gender'] = label_encoderGenderX.transform(bankchurners20columns['Gender'])

# %%
# bankchurners20columns['Gender'].value_counts()
